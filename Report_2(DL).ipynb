# %% [markdown]
# # Ensembling of simple CNN models to get best possible accuracy for MNIST fashion dataset

# %% [markdown]
# Importing required libraries

# %%
import tensorflow as tf
from numpy import unique, argmax
from keras.datasets import fashion_mnist
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, BatchNormalization
from tensorflow.keras.utils import plot_model
from matplotlib import pyplot
import matplotlib.pyplot as plt
import numpy as np   
from tensorflow.keras import layers

# %% [markdown]
# Loading the MNIST fashion dataset and reshaping the training and testing images

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], x_test.shape[2], 1))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Shape of input, output training and testing images

# %%
print('Fashion MNIST Dataset Shape:')
print('X_train: ' + str(x_train.shape))
print('Y_train: ' + str(y_train.shape))
print('X_test:  '  + str(x_test.shape))
print('Y_test:  '  + str(y_test.shape))
# Out:
# Fashion MNIST Dataset Shape:
# X_train: (60000, 28, 28, 1)
# Y_train: (60000,)
# X_test:  (10000, 28, 28, 1)
# Y_test:  (10000,)

# %% [markdown]
# Normalization of input images

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# Label number & respective images
#
# Label        	Description
#
# 0	  -T-shirt/top
#
# 1-Trowser
#
# 2-	Pullover
#
# 3-	Dress
#
# 4-	Coat
#
# 5	-Sandal
#
# 6-	Shirt
#
# 7	-Sneaker
#
# 8-	Bag
#
# 9-	Ankle Boot

# %% [markdown]
# visualization of input images from training mnist fashion dataset

# %%
fig = plt.figure(figsize=(5,5))
for i in range(9):
  ax = fig.add_subplot(3,3, i+1, xticks=[], yticks=[])
  ax.imshow(np.squeeze(x_train[i]), cmap='gray')
  ax.set_title(y_train[i])

# %% [markdown]
# creating preprocessing layers for doing data augmentation ,mainly we are doing random rotation and random flip, and we will use these layers in models not in dataset

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

# %% [markdown]
# Model 1 (Name-M3, boz of 3*3 kernel size ), having 10 conv. layers followed by batchnormalization and final output layer

# %%
model1 = tf.keras.Sequential([
data_augmentation,


layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
layers.BatchNormalization(),


layers.Conv2D(48, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(64, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(80, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(96, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(112, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(128, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(144, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(160, (3,3), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(176, (3,3), activation='relu'),
layers.BatchNormalization(),

layers.Flatten(),

layers.Dense(10, activation='softmax'),
])

# %% [markdown]
# Compiling the model 1 ,summary and model 1 architecture

# %%
model1.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=1e-6), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history1 = model1.fit(x_train, y_train, epochs=5, batch_size=224, verbose=2, validation_split=None)

model1.summary()
model1.save('saved_models/model1.hdf5')
plot_model(model1, 'model1.jpg', show_shapes=True)
# Out:
# Epoch 1/5
# 268/268 - 40s - loss: 0.4793 - accuracy: 0.8321 - 40s/epoch - 151ms/step
# Epoch 2/5
# 268/268 - 39s - loss: 0.4730 - accuracy: 0.8324 - 39s/epoch - 145ms/step
# Epoch 3/5
# 268/268 - 39s - loss: 0.4695 - accuracy: 0.8331 - 39s/epoch - 145ms/step
# Epoch 4/5
# 268/268 - 39s - loss: 0.4772 - accuracy: 0.8325 - 39s/epoch - 146ms/step
# Epoch 5/5
# 268/268 - 39s - loss: 0.4703 - accuracy: 0.8339 - 39s/epoch - 145ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  batch_normalization (BatchN  (None, 26, 26, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 48)        13872
#
#  batch_normalization_1 (Batc  (None, 24, 24, 48)       192
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 22, 22, 64)        27712
#
#  batch_normalization_2 (Batc  (None, 22, 22, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 80)        46160
#
#  batch_normalization_3 (Batc  (None, 20, 20, 80)       320
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 96)        69216
#
#  batch_normalization_4 (Batc  (None, 18, 18, 96)       384
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 112)       96880
#
#  batch_normalization_5 (Batc  (None, 16, 16, 112)      448
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)       129152
#
#  batch_normalization_6 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 144)       166032
#
#  batch_normalization_7 (Batc  (None, 12, 12, 144)      576
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 160)       207520
#
#  batch_normalization_8 (Batc  (None, 10, 10, 160)      640
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 176)         253616
#
#  batch_normalization_9 (Batc  (None, 8, 8, 176)        704
#  hNormalization)
#
#  flatten (Flatten)           (None, 11264)             0
#
#  dense (Dense)               (None, 10)                112650
#
# =================================================================
# Total params: 1,127,290
# Trainable params: 1,125,210
# Non-trainable params: 2,080
# _________________________________________________________________

# %% [markdown]
# Model 2 (Name-M5, boz of 5*5 kernel size ), having 5 conv. layers followed by batchnormalization and final output layer

# %%
model2 = tf.keras.Sequential([
data_augmentation,

layers.Conv2D(32, (5,5), activation='relu', input_shape=(28,28,1)),
layers.BatchNormalization(),


layers.Conv2D(64, (5,5), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(96, (5,5), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(128, (5,5), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(160, (5,5), activation='relu'),
layers.BatchNormalization(),

layers.Flatten(),

layers.Dense(10, activation='softmax'),

])

# %% [markdown]
# Compiling the model 2 ,summary and model 2 architecture

# %%
model2.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history2 = model2.fit(x_train, y_train, epochs=10, batch_size=224, verbose=2, validation_split=None)

model2.summary()
model2.save('saved_models/model2.hdf5')
plot_model(model2, 'model2.jpg', show_shapes=True)
# Out:
# Epoch 1/10
# 268/268 - 20s - loss: 0.3592 - accuracy: 0.8704 - 20s/epoch - 73ms/step
# Epoch 2/10
# 268/268 - 18s - loss: 0.3621 - accuracy: 0.8690 - 18s/epoch - 67ms/step
# Epoch 3/10
# 268/268 - 18s - loss: 0.3558 - accuracy: 0.8724 - 18s/epoch - 67ms/step
# Epoch 4/10
# 268/268 - 18s - loss: 0.3511 - accuracy: 0.8734 - 18s/epoch - 66ms/step
# Epoch 5/10
# 268/268 - 18s - loss: 0.3499 - accuracy: 0.8755 - 18s/epoch - 67ms/step
# Epoch 6/10
# 268/268 - 18s - loss: 0.3516 - accuracy: 0.8740 - 18s/epoch - 67ms/step
# Epoch 7/10
# 268/268 - 18s - loss: 0.3438 - accuracy: 0.8759 - 18s/epoch - 68ms/step
# Epoch 8/10
# 268/268 - 18s - loss: 0.3457 - accuracy: 0.8744 - 18s/epoch - 68ms/step
# Epoch 9/10
# 268/268 - 18s - loss: 0.3396 - accuracy: 0.8788 - 18s/epoch - 67ms/step
# Epoch 10/10
# 268/268 - 18s - loss: 0.3370 - accuracy: 0.8784 - 18s/epoch - 67ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 28, 28, 1)         0
#
#  conv2d_20 (Conv2D)          (None, 24, 24, 32)        832
#
#  batch_normalization_20 (Bat  (None, 24, 24, 32)       128
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 20, 20, 64)        51264
#
#  batch_normalization_21 (Bat  (None, 20, 20, 64)       256
#  chNormalization)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 96)        153696
#
#  batch_normalization_22 (Bat  (None, 16, 16, 96)       384
#  chNormalization)
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 128)       307328
#
#  batch_normalization_23 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 160)         512160
#
#  batch_normalization_24 (Bat  (None, 8, 8, 160)        640
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 10240)             0
#
#  dense_3 (Dense)             (None, 10)                102410
#
# =================================================================
# Total params: 1,129,610
# Trainable params: 1,128,650
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# Model 3 (Name-M7, boz of 7*7 kernel size ), having 4 conv. layers followed by batchnormalization and final output layer

# %%
model3 = tf.keras.Sequential([
data_augmentation,

layers.Conv2D(48, (7,7), activation='relu', input_shape=(28,28,1)),
layers.BatchNormalization(),


layers.Conv2D(96, (7,7), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(144, (7,7), activation='relu'),
layers.BatchNormalization(),


layers.Conv2D(192, (7,7), activation='relu'),
layers.BatchNormalization(),

layers.Flatten(),

layers.Dense(10, activation='softmax'),

])

# %% [markdown]
# Compiling the model 3 ,summary and model 3 architecture

# %%
model3.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=1e-6), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history3 = model3.fit(x_train, y_train, epochs=5, batch_size=324, verbose=2, validation_split=None)

model3.summary()
model3.save('saved_models/model3.hdf5')
plot_model(model3, 'model3.jpg', show_shapes=True)
# Out:
# Epoch 1/5
# 186/186 - 21s - loss: 0.5921 - accuracy: 0.7894 - 21s/epoch - 113ms/step
# Epoch 2/5
# 186/186 - 18s - loss: 0.5843 - accuracy: 0.7938 - 18s/epoch - 98ms/step
# Epoch 3/5
# 186/186 - 18s - loss: 0.5829 - accuracy: 0.7923 - 18s/epoch - 99ms/step
# Epoch 4/5
# 186/186 - 18s - loss: 0.5828 - accuracy: 0.7934 - 18s/epoch - 98ms/step
# Epoch 5/5
# 186/186 - 18s - loss: 0.5763 - accuracy: 0.7959 - 18s/epoch - 98ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 28, 28, 1)         0
#
#  conv2d_10 (Conv2D)          (None, 22, 22, 48)        2400
#
#  batch_normalization_10 (Bat  (None, 22, 22, 48)       192
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 96)        225888
#
#  batch_normalization_11 (Bat  (None, 16, 16, 96)       384
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 10, 10, 144)       677520
#
#  batch_normalization_12 (Bat  (None, 10, 10, 144)      576
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 192)         1354944
#
#  batch_normalization_13 (Bat  (None, 4, 4, 192)        768
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 3072)              0
#
#  dense_1 (Dense)             (None, 10)                30730
#
# =================================================================
# Total params: 2,293,402
# Trainable params: 2,292,442
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# Ensembling 1 => M3+M3+M3
#
# Ensembling 2 => M5+M5+M5
#
# Ensembling 3 => M7+M7+M7
#
# Ensembling 4 => M3+M5+M7
#
# printing the accuracies for all 3 models M3, M5 and M7 separately and also accuracies for ensembling 1, 2, 3 and 4 for test mnist fashion data

# %%
from keras.models import load_model
from sklearn.metrics import accuracy_score

model1 = load_model('saved_models/model1.hdf5')      # loading the saved models
model2 = load_model('saved_models/model2.hdf5')
model3 = load_model('saved_models/model3.hdf5')


models1 = [model1, model1, model1]
models2 = [model2, model2, model2]
models3 = [model3, model3, model3]
models4 = [model1, model2, model3]


preds1 = [model.predict(x_test) for model in models1]
preds1=np.array(preds1)             # converting pred. into array
summed1= np.sum(preds1, axis=0)         # adding pred. of diff. models

ensemble_prediction1 = np.argmax(summed1, axis=1)    # prediction 

preds2 = [model.predict(x_test) for model in models2]
preds2=np.array(preds2)
summed2 = np.sum(preds2, axis=0)

ensemble_prediction2 = np.argmax(summed2, axis=1)

preds3 = [model.predict(x_test) for model in models3]
preds3=np.array(preds3)
summed3 = np.sum(preds3, axis=0)

ensemble_prediction3 = np.argmax(summed3, axis=1)

preds4 = [model.predict(x_test) for model in models4]
preds4=np.array(preds4)
summed4 = np.sum(preds4, axis=0)

ensemble_prediction4 = np.argmax(summed4, axis=1)


loss, accuracy1= model1.evaluate(x_test, y_test, verbose=0.0 )
loss, accuracy2= model2.evaluate(x_test, y_test, verbose=0.0 )
loss, accuracy3= model3.evaluate(x_test, y_test, verbose=0.0 )

ensemble_accuracy1= accuracy_score(y_test, ensemble_prediction1)
ensemble_accuracy2= accuracy_score(y_test, ensemble_prediction2)
ensemble_accuracy3= accuracy_score(y_test, ensemble_prediction3)
ensemble_accuracy4= accuracy_score(y_test, ensemble_prediction4)

# printing all accuracies together

print('Accuracy of model 1:', accuracy1*100)

print('Accuracy of model 2:', accuracy2*100)

print('Accuracy of model 3:', accuracy3*100)

print('Accuracy of ensemble(M3+M3+M3) is:', ensemble_accuracy1*100)

print('Accuracy of ensemble(M5+M5+M5) is:', ensemble_accuracy2*100)

print('Accuracy of ensemble(M7+M7+M7) is:', ensemble_accuracy3*100)

print('Accuracy of ensemble(M3+M5+M7) is:', ensemble_accuracy4*100)

# %% [markdown]
# Previously we did ensembling for M3+M5+M7 but with equal weightage to all 3 models and now we will ensemble by giving best possible weights to all 3 models M3, M5 and M7 and find the test accuracy and we will compare it with results of ensembling 4

# %%
models4 = [model1, model2, model3]

preds4 = [model.predict(x_test) for model in models4]
preds4=np.array(preds4)
weights=[0.8, 0.2, 0.2]      # providing weightage to M3, M5 and M7 

weighted_preds=np.tensordot(preds4, weights, axes=((0),(0)))
weighted_ensemble_prediction =np.argmax(weighted_preds, axis=1)

weighted_accuracy=accuracy_score(y_test, weighted_ensemble_prediction)

#  printing all the various accuracies again 

print('Accuracy of model 1:', accuracy1*100)

print('Accuracy of model 2:', accuracy2*100)

print('Accuracy of model 3:', accuracy3*100)

print('Accuracy of ensemble(M3+M5+M7) is:', ensemble_accuracy4*100)

print('Accuracy of weighted ensemble(0.8*M3+0.2*M5+0.2*M7) is:', weighted_accuracy*100)

# %% [markdown]
# Summary-- In report 1 it is said that, ensembling of different models can give you the better accuracy relative to accuracies of individual models and it is exactly what i showed in this code for the paper that we choose for our term project, as u can see accuracy of ensemble 4 if more than any individual model ( M3, M5 and M7) and further accuracy of weighted ensemble is better than all remaining
#
# Data -> MNIST fashion dataset
#
# Note-> if u don't get the same accuracies as shown above please train the models again and again by changing the learning rate boz i experinced the same thing when i run the code after some days, I changed the lr values to 1e-3, 1e-4, 1e-6 and finaly the values given above.
#
# Also run the code in one go , boz the models which are saved in the folder of COLAB are temporary, they just vanish after some time or if u only run the code partially and remaining code after some time.
#
# Also if u find any error/problem/dicrepancy b/w results of this code and results u are getting during runing the code please contact me
